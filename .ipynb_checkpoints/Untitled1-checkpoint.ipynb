# %%
import pandas as pd

# %%
df = pd.read_csv('lid_all.csv')

# %%
df.head
# Out:
# <bound method NDFrame.head of            id  sentence label
# 0           0  sangitla   MAR
# 1           0       mya   MAR
# 2           0  surprise   ENG
# 3           0      hoil   MAR
# 4           0   kalmadi   OTH
# ...       ...       ...   ...
# 136385  11999        bc   OTH
# 136386  11999  kohlichi   MAR
# 136387  11999     layki   MAR
# 136388  11999      aahe   MAR
# 136389  11999        ka   MAR
#
# [136390 rows x 3 columns]>

# %%
x = df.groupby('id')
ds = []
for i in range(len(x)):
    try:
        sentence_df = x.get_group(i)
        words = list(sentence_df.iloc[:,1])
        tags = list(sentence_df.iloc[:,2])
        #print(words,tags)
        ds.append(words)
        ds.append(tags)
        #break
ds[0]
# Out:
#   Cell In[25], line 12
#     ds[0]
#          ^
# IndentationError: unexpected unindent
